# %% [markdown]
# # Basic Preprocessing in NLP
#
# ## Case Folding, Stop Word Removal and Lemmatization

# %%
# checking spacy's version
# !python -m spacy info
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.7.6
# Location         /usr/local/lib/python3.10/dist-packages/spacy
# Platform         Linux-6.1.85+-x86_64-with-glibc2.35
# Python version   3.10.12
# Pipelines        en_core_web_sm (3.7.1)

# %%
# importing the spacy library
import spacy

# %%
# loading the spacy model (also known as trained pipelines)
nlp = spacy.load('en_core_web_sm')

# %%
# sample sentence
corpus = "Energy cannot be created or destroyed, it can only be changed from one form to another. - Albert Einstein"

# processing the text (tokenizing) to return a Doc object
doc = nlp(corpus)

# %% [markdown]
# ## Case Folding

# %% [markdown]
# Case Folding is just converting all words to lower case to normalize the text by removing variations and reducing complexity that helps with tasks such as text comparison or search.

# %%
# case folding uses the lower_ attribute
print([t.lower_ for t in doc])
# Out:
# ['energy', 'can', 'not', 'be', 'created', 'or', 'destroyed', ',', 'it', 'can', 'only', 'be', 'changed', 'from', 'one', 'form', 'to', 'another', '.', '-', 'albert', 'einstein']

# %% [markdown]
# ## Stop Word Removal

# %% [markdown]
# The spaCy libary contains a default stop word list. The list can be viewed, add your own words and even remove the words.

# %%
# viewing the default stop word list by spacy
print(nlp.Defaults.stop_words)
print(f"total = {len(nlp.Defaults.stop_words)}")
# Out:
# {'none', 'me', 'although', '‘s', 'we', 'ever', 'it', 'own', 'becoming', 'whereas', 'fifteen', 'somehow', 'wherever', 'under', 'front', 'many', 'or', 'unless', 'nowhere', 'to', 'nor', 'now', 'sixty', 'has', 'around', 'up', 're', 'ourselves', 'since', 'behind', 'whether', 'beyond', '‘re', '’s', 'everyone', 'between', 'by', 'fifty', 'they', 'themselves', 'already', 'thence', 'various', 'afterwards', 'mostly', 'formerly', 'so', 'which', 'how', 'doing', 'may', 'i', 'too', 'at', 'into', 'less', 'becomes', 'being', 'should', 'been', 'towards', 'really', 'several', 'where', 'as', 'another', 'made', 'down', 'latter', 'whom', '’m', 'except', 'most', 'n‘t', 'why', 'go', 'onto', 'part', 'name', 'be', 'move', 'regarding', 'these', 'nine', 'using', 'somewhere', 'became', 'else', 'forty', 'about', 'mine', 'those', 'perhaps', 'but', 'a', 'have', 'thru', 'them', 'there', 'within', 'herself', 'this', 'against', 'throughout', 'per', 'three', 'amongst', 'thereafter', 'toward', 'each', 'because', 'besides', 'of', 'twelve', 'what', 'never', 'before', 'get', 'all', 'twenty', 'one', 'n’t', 'therein', 'every', 'moreover', 'whatever', 'will', 'via', 'indeed', 'above', 'beside', 'when', 'might', "'m", 'further', "'d", 'yet', 'anything', 'would', 'wherein', 'make', 'ca', 'nobody', 'are', 'is', 'both', 'see', 'back', 'my', 'seeming', 'below', 'more', 'and', 'bottom', '’d', 'am', 'some', 'hence', 'third', 'their', 'latterly', '‘ll', 'thereby', 'hereupon', 'everywhere', 'ours', 'otherwise', 'take', 'same', 'after', 'put', "'ve", 'everything', 'thereupon', 'much', 'any', '’ll', 'neither', 'were', 'say', 'do', "'ll", 'therefore', 'seem', 'had', 'over', 'two', 'often', 'in', 'elsewhere', 'namely', 'other', 'others', 'he', 'us', 'whither', 'you', 'always', 'itself', 'through', 'beforehand', 'also', 'off', 'its', 'top', 'give', 'something', 'first', 'then', '’re', 'used', 'himself', 'whereafter', 'whereupon', 'your', 'cannot', 'someone', 'meanwhile', 'she', 'anyhow', 'either', 'hereby', 'must', 'eleven', 'side', 'among', 'hers', 'full', 'yours', 'become', 'for', 'without', 'due', 'least', 'did', 'who', 'together', 'former', 'our', 'while', '’ve', 'anyway', 'almost', 'yourself', "'s", 'with', 'his', 'across', 'seemed', 'seems', 'hundred', 'during', 'until', 'that', 'whose', 'five', 'not', 'no', 'from', 'can', 'whereby', 'rather', 'show', 'herein', 'her', 'whole', 'was', 'amount', 'once', 'along', 'please', 'here', 'six', 'hereafter', 'call', '‘m', 'serious', 'if', 'anywhere', 'anyone', 'such', 'however', 'whence', 'upon', 'next', 'alone', 'thus', 'quite', 'nothing', 'does', 'whoever', 'though', 'few', 'out', 'just', 'an', 'done', 'ten', 'only', 'myself', 'nevertheless', 'sometime', 'even', 'last', 'still', '‘d', 'empty', 'could', 'enough', 'sometimes', 'whenever', "n't", 'well', 'the', 'very', 'on', "'re", 'yourselves', 'eight', 'four', 'him', 'keep', '‘ve', 'again', 'than', 'noone'}
# total = 326

# %%
# adding my own stop word "hello"
nlp.Defaults.stop_words.add("hello")
print(nlp.Defaults.stop_words)
print(f"new total = {len(nlp.Defaults.stop_words)}")
# Out:
# {'none', 'me', 'although', '‘s', 'we', 'ever', 'it', 'own', 'becoming', 'whereas', 'fifteen', 'somehow', 'wherever', 'under', 'front', 'many', 'or', 'unless', 'nowhere', 'to', 'nor', 'now', 'sixty', 'has', 'around', 'up', 're', 'ourselves', 'since', 'behind', 'whether', 'beyond', '‘re', '’s', 'everyone', 'between', 'by', 'fifty', 'they', 'themselves', 'already', 'thence', 'various', 'afterwards', 'mostly', 'formerly', 'so', 'which', 'how', 'doing', 'may', 'i', 'too', 'at', 'into', 'less', 'becomes', 'being', 'should', 'been', 'towards', 'really', 'several', 'where', 'as', 'another', 'made', 'down', 'latter', 'whom', '’m', 'except', 'most', 'n‘t', 'why', 'go', 'onto', 'part', 'name', 'be', 'move', 'regarding', 'these', 'nine', 'using', 'somewhere', 'became', 'else', 'forty', 'about', 'mine', 'those', 'perhaps', 'but', 'a', 'have', 'thru', 'them', 'there', 'within', 'herself', 'this', 'against', 'throughout', 'per', 'three', 'amongst', 'thereafter', 'toward', 'each', 'because', 'besides', 'of', 'twelve', 'what', 'never', 'before', 'get', 'all', 'twenty', 'one', 'n’t', 'therein', 'every', 'moreover', 'whatever', 'will', 'via', 'indeed', 'above', 'beside', 'when', 'might', "'m", 'further', "'d", 'yet', 'anything', 'would', 'wherein', 'make', 'ca', 'nobody', 'are', 'is', 'both', 'see', 'back', 'my', 'seeming', 'below', 'more', 'and', 'bottom', '’d', 'am', 'some', 'hence', 'third', 'their', 'latterly', '‘ll', 'thereby', 'hereupon', 'everywhere', 'ours', 'hello', 'otherwise', 'take', 'same', 'after', 'put', "'ve", 'everything', 'thereupon', 'much', 'any', '’ll', 'neither', 'were', 'say', 'do', "'ll", 'therefore', 'seem', 'had', 'over', 'two', 'often', 'in', 'elsewhere', 'namely', 'other', 'others', 'he', 'us', 'whither', 'you', 'always', 'itself', 'through', 'beforehand', 'also', 'off', 'its', 'top', 'give', 'something', 'first', 'then', '’re', 'used', 'himself', 'whereafter', 'whereupon', 'your', 'cannot', 'someone', 'meanwhile', 'she', 'anyhow', 'either', 'hereby', 'must', 'eleven', 'side', 'among', 'hers', 'full', 'yours', 'become', 'for', 'without', 'due', 'least', 'did', 'who', 'together', 'former', 'our', 'while', '’ve', 'anyway', 'almost', 'yourself', "'s", 'with', 'his', 'across', 'seemed', 'seems', 'hundred', 'during', 'until', 'that', 'whose', 'five', 'not', 'no', 'from', 'can', 'whereby', 'rather', 'show', 'herein', 'her', 'whole', 'was', 'amount', 'once', 'along', 'please', 'here', 'six', 'hereafter', 'call', '‘m', 'serious', 'if', 'anywhere', 'anyone', 'such', 'however', 'whence', 'upon', 'next', 'alone', 'thus', 'quite', 'nothing', 'does', 'whoever', 'though', 'few', 'out', 'just', 'an', 'done', 'ten', 'only', 'myself', 'nevertheless', 'sometime', 'even', 'last', 'still', '‘d', 'empty', 'could', 'enough', 'sometimes', 'whenever', "n't", 'well', 'the', 'very', 'on', "'re", 'yourselves', 'eight', 'four', 'him', 'keep', '‘ve', 'again', 'than', 'noone'}
# new total = 327

# %%
# returning everything back to normal by removing my stop word
nlp.Defaults.stop_words.remove("hello")
print(nlp.Defaults.stop_words)
print(f"total = {len(nlp.Defaults.stop_words)}")
# Out:
# {'none', 'me', 'although', '‘s', 'we', 'ever', 'it', 'own', 'becoming', 'whereas', 'fifteen', 'somehow', 'wherever', 'under', 'front', 'many', 'or', 'unless', 'nowhere', 'to', 'nor', 'now', 'sixty', 'has', 'around', 'up', 're', 'ourselves', 'since', 'behind', 'whether', 'beyond', '‘re', '’s', 'everyone', 'between', 'by', 'fifty', 'they', 'themselves', 'already', 'thence', 'various', 'afterwards', 'mostly', 'formerly', 'so', 'which', 'how', 'doing', 'may', 'i', 'too', 'at', 'into', 'less', 'becomes', 'being', 'should', 'been', 'towards', 'really', 'several', 'where', 'as', 'another', 'made', 'down', 'latter', 'whom', '’m', 'except', 'most', 'n‘t', 'why', 'go', 'onto', 'part', 'name', 'be', 'move', 'regarding', 'these', 'nine', 'using', 'somewhere', 'became', 'else', 'forty', 'about', 'mine', 'those', 'perhaps', 'but', 'a', 'have', 'thru', 'them', 'there', 'within', 'herself', 'this', 'against', 'throughout', 'per', 'three', 'amongst', 'thereafter', 'toward', 'each', 'because', 'besides', 'of', 'twelve', 'what', 'never', 'before', 'get', 'all', 'twenty', 'one', 'n’t', 'therein', 'every', 'moreover', 'whatever', 'will', 'via', 'indeed', 'above', 'beside', 'when', 'might', "'m", 'further', "'d", 'yet', 'anything', 'would', 'wherein', 'make', 'ca', 'nobody', 'are', 'is', 'both', 'see', 'back', 'my', 'seeming', 'below', 'more', 'and', 'bottom', '’d', 'am', 'some', 'hence', 'third', 'their', 'latterly', '‘ll', 'thereby', 'hereupon', 'everywhere', 'ours', 'otherwise', 'take', 'same', 'after', 'put', "'ve", 'everything', 'thereupon', 'much', 'any', '’ll', 'neither', 'were', 'say', 'do', "'ll", 'therefore', 'seem', 'had', 'over', 'two', 'often', 'in', 'elsewhere', 'namely', 'other', 'others', 'he', 'us', 'whither', 'you', 'always', 'itself', 'through', 'beforehand', 'also', 'off', 'its', 'top', 'give', 'something', 'first', 'then', '’re', 'used', 'himself', 'whereafter', 'whereupon', 'your', 'cannot', 'someone', 'meanwhile', 'she', 'anyhow', 'either', 'hereby', 'must', 'eleven', 'side', 'among', 'hers', 'full', 'yours', 'become', 'for', 'without', 'due', 'least', 'did', 'who', 'together', 'former', 'our', 'while', '’ve', 'anyway', 'almost', 'yourself', "'s", 'with', 'his', 'across', 'seemed', 'seems', 'hundred', 'during', 'until', 'that', 'whose', 'five', 'not', 'no', 'from', 'can', 'whereby', 'rather', 'show', 'herein', 'her', 'whole', 'was', 'amount', 'once', 'along', 'please', 'here', 'six', 'hereafter', 'call', '‘m', 'serious', 'if', 'anywhere', 'anyone', 'such', 'however', 'whence', 'upon', 'next', 'alone', 'thus', 'quite', 'nothing', 'does', 'whoever', 'though', 'few', 'out', 'just', 'an', 'done', 'ten', 'only', 'myself', 'nevertheless', 'sometime', 'even', 'last', 'still', '‘d', 'empty', 'could', 'enough', 'sometimes', 'whenever', "n't", 'well', 'the', 'very', 'on', "'re", 'yourselves', 'eight', 'four', 'him', 'keep', '‘ve', 'again', 'than', 'noone'}
# total = 326

# %%
# using stop words to remove unnecessary words
print([t for t in doc if not t.is_stop])
# Out:
# [Energy, created, destroyed, ,, changed, form, ., -, Albert, Einstein]

# %% [markdown]
# ## Lemmatization

# %% [markdown]
# Through lemmatization it is possible to break a word down and returning it to its base or root form.

# %%
for t in doc:
  t_text = t.text
  t_lemma = t.lemma_  # lemmatization uses lemma_ attribute
  print(f"{t_text:<15}{t_lemma:<15}")
# Out:
# Energy         energy
# can            can
# not            not
# be             be
# created        create
# or             or
# destroyed      destroy
# ,              ,
# it             it
# can            can
# only           only
# be             be
# changed        change
# from           from
# one            one
# form           form
# to             to
# another        another
# .              .
# -              -
# Albert         Albert
# Einstein       Einstein
